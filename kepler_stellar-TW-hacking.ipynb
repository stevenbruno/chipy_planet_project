# %% [markdown]
# ### Kepler Stellar

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('keplerstellar.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#      st_delivname      kepid           tm_designation         ra        dec  \
# 0  q1_q12_stellar   10000009  2MASS J19050117+4657496  286.25488  46.963791
# 1  q1_q12_stellar   10000069  2MASS J19050855+4656274  286.28568  46.940960
# 2  q1_q12_stellar   10000083  2MASS J19051088+4658236  286.29535  46.973221
# 3  q1_q12_stellar   10000090  2MASS J19051171+4656443  286.29883  46.945660
# 4  q1_q12_stellar  100000925                      NaN        NaN        NaN
#
#    kepmag  teff     teff_prov   logg     logg_prov  ...  dens prov_sec  dist  \
# 0  11.690  6852  Pinsonneault  4.144  Pinsonneault  ...   NaN      NaN   NaN
# 1  15.547  5925  Pinsonneault  4.522  Pinsonneault  ...   NaN      NaN   NaN
# 2  15.276  6142  Pinsonneault  4.384  Pinsonneault  ...   NaN      NaN   NaN
# 3  15.307  6113  Pinsonneault  4.487  Pinsonneault  ...   NaN      NaN   NaN
# 4     NaN  5780         Solar  4.438         Solar  ...   NaN      NaN   NaN
#
# ...

# %% [markdown]
# #### Column Definitions
#  - **kepid** kepler ID
#  - **ra** right ascension
#  - **dec** declination angle
#  - **kepmag** Kepler-band magnitude
#  - **teff** The photospheric temperature of the star
#  - **logg** The base-10 logarithm of the acceleration due to gravity at the surface of the star
#  - **feh** The base-10 logarithm of the Fe to H ratio at the surface of the star, normalized by the solar Fe to H ratio
#  - **radius** The photospheric radius of the star
#  - **mass** The mass of the star
#  - **dens** The density of the star
#  - **nconfp** number of confirmed planets in orbit
#  - **nkoi** number of kepler objects of interest
#  - **ntce** Number of Kepler TCEs identified in a system

# %%
confirmed_host = 0 < df['nconfp']

# %%
confirmed_df = df[confirmed_host]

# %%
confirmed_df.head()
# Out:
#        st_delivname     kepid           tm_designation         ra        dec  \
# 88   q1_q12_stellar  10000941  2MASS J19071664+4654420  286.81937  46.911690
# 116  q1_q12_stellar  10001368  2MASS J19082071+4656449  287.08630  46.945808
# 140  q1_q12_stellar  10001893  2MASS J19093340+4659041  287.38919  46.984489
# 194  q1_q12_stellar  10002866  2MASS J19113746+4656159  287.90610  46.937771
# 267  q1_q12_stellar  10004519  2MASS J19145618+4656218  288.73407  46.939388
#
#      kepmag   teff     teff_prov   logg     logg_prov  ...  dens prov_sec  \
# 88   13.632   5056  Pinsonneault  4.565  Pinsonneault  ...   NaN      NaN
# 116  14.083   5986           KIC  4.376           KIC  ...   NaN      NaN
# 140  15.846  10697           KIC  3.999           KIC  ...   NaN      NaN
# 194  15.063   5344  Pinsonneault  4.615  Pinsonneault  ...   NaN      NaN
# 267  15.439   5920           KIC  4.590           KIC  ...   NaN      NaN
#
# ...

# %%
confirmed_df.shape
# Out:
# (8274, 24)

# %%
df.shape
# Out:
# (990244, 24)

# %%
list(df)
# Out:
# ['st_delivname',
#  'kepid',
#  'tm_designation',
#  'ra',
#  'dec',
#  'kepmag',
#  'teff',
#  'teff_prov',
#  'logg',
#  'logg_prov',
#  'feh',
#  'feh_prov',
#  'radius',
#  'mass',
#  'dens',
#  'prov_sec',
#  'dist',
#  'nconfp',
#  'nkoi',
#  'ntce',
#  'st_quarters',
#  'jmag',
#  'hmag',
#  'kmag']

# %%
stellar = df.drop(['st_delivname', 'kepid', 'tm_designation', 'ra', 'dec', 'kepmag', 'teff_prov', 'logg_prov', 'feh_prov', 'prov_sec', 'dist', 'nkoi', 'ntce', 'st_quarters', 'jmag', 'hmag', 'kmag'], axis=1)
stellar.shape
# Out:
# (990244, 7)

# %%
stellar.head(10)
# Out:
#    teff   logg  feh  radius  mass  dens  nconfp
# 0  6852  4.144 -0.2   1.651   NaN   NaN       0
# 1  5925  4.522 -0.2   0.913   NaN   NaN       0
# 2  6142  4.384 -0.2   1.097   NaN   NaN       0
# 3  6113  4.487 -0.2   0.979   NaN   NaN       0
# 4  5780  4.438  0.0   1.000   NaN   NaN       0
# 5  5780  4.438  0.0   1.000   NaN   NaN       0
# 6  5780  4.438  0.0   1.000   NaN   NaN       0
# 7  5780  4.438  0.0   1.000   NaN   NaN       0
# 8  5780  4.438  0.0   1.000   NaN   NaN       0
# 9  5780  4.438  0.0   1.000   NaN   NaN       0

# %%
stellar.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  990244.000000  990244.000000  990244.000000  990244.000000
# mean     5674.616938       4.200098      -0.174397       3.162848
# std       802.762263       0.682550       0.251700      10.862114
# min      2500.000000      -0.154000      -2.567000       0.104000
# 25%      5207.000000       4.218000      -0.260000       0.836000
# 50%      5776.000000       4.446000      -0.200000       1.000000
# 75%      6129.000000       4.544000      -0.034000       1.374000
# max     27730.000000       6.158000       1.000000     300.749000
#
#                 mass          dens         nconfp
# count  787129.000000  7.871290e+05  990244.000000
# mean        1.102479  1.711643e+00       0.011862
# std         0.508014  3.359078e+00       0.149630
# min         0.086000  1.851000e-07       0.000000
# 25%         0.850000  5.319000e-01       0.000000
# 50%         0.988300  1.435000e+00       0.000000
# ...

# %%
stellar.drop('dens', axis=1, inplace=True)
stellar.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  990244.000000  990244.000000  990244.000000  990244.000000
# mean     5674.616938       4.200098      -0.174397       3.162848
# std       802.762263       0.682550       0.251700      10.862114
# min      2500.000000      -0.154000      -2.567000       0.104000
# 25%      5207.000000       4.218000      -0.260000       0.836000
# 50%      5776.000000       4.446000      -0.200000       1.000000
# 75%      6129.000000       4.544000      -0.034000       1.374000
# max     27730.000000       6.158000       1.000000     300.749000
#
#                 mass         nconfp
# count  787129.000000  990244.000000
# mean        1.102479       0.011862
# std         0.508014       0.149630
# min         0.086000       0.000000
# 25%         0.850000       0.000000
# 50%         0.988300       0.000000
# 75%         1.138000       0.000000
# max         3.736000       8.000000

# %%
stellar['has_habitable'] = np.nan
stellar.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  990244.000000  990244.000000  990244.000000  990244.000000
# mean     5674.616938       4.200098      -0.174397       3.162848
# std       802.762263       0.682550       0.251700      10.862114
# min      2500.000000      -0.154000      -2.567000       0.104000
# 25%      5207.000000       4.218000      -0.260000       0.836000
# 50%      5776.000000       4.446000      -0.200000       1.000000
# 75%      6129.000000       4.544000      -0.034000       1.374000
# max     27730.000000       6.158000       1.000000     300.749000
#
#                 mass         nconfp  has_habitable
# count  787129.000000  990244.000000            0.0
# mean        1.102479       0.011862            NaN
# std         0.508014       0.149630            NaN
# min         0.086000       0.000000            NaN
# 25%         0.850000       0.000000            NaN
# 50%         0.988300       0.000000            NaN
# ...

# %% [markdown]
# Counting how many stars have exoplanets

# %%
stellar[stellar['nconfp'] > 0].shape
# Out:
# (8274, 7)

# %%
habitable = pd.read_csv('habitable.csv')
habitable.describe()
# Out:
#          koi_steff  koi_slogg   koi_smet   koi_srad  koi_smass  nconfp  \
# count    51.000000  51.000000  51.000000  51.000000  51.000000    51.0
# mean   4895.058824   4.581137  -0.170588   0.786784   0.754647     1.0
# std     917.552296   0.228058   0.351280   0.424417   0.254537     0.0
# min    2661.000000   3.629000  -1.460000   0.116000   0.094000     1.0
# 25%    4166.000000   4.486500  -0.340000   0.542500   0.555500     1.0
# 50%    4821.000000   4.615000  -0.100000   0.701000   0.748000     1.0
# 75%    5627.500000   4.709500   0.020000   0.941500   0.916000     1.0
# max    6553.000000   5.283000   0.460000   3.204000   1.592000     1.0
#
#        has_habitable
# count           51.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
habitable.head()
# Out:
#    koi_steff  koi_slogg  koi_smet  koi_srad  koi_smass  nconfp  has_habitable
# 0     3950.0      4.754     -0.46     0.493      0.502       1              1
# 1     3593.0      4.757      0.26     0.491      0.503       1              1
# 2     2661.0      5.283      0.00     0.116      0.094       1              1
# 3     4016.0      4.658      0.02     0.599      0.595       1              1
# 4     5637.0      4.399     -0.30     0.943      0.813       1              1

# %%
stellar.head()
# Out:
#    teff   logg  feh  radius  mass  nconfp  has_habitable
# 0  6852  4.144 -0.2   1.651   NaN       0            NaN
# 1  5925  4.522 -0.2   0.913   NaN       0            NaN
# 2  6142  4.384 -0.2   1.097   NaN       0            NaN
# 3  6113  4.487 -0.2   0.979   NaN       0            NaN
# 4  5780  4.438  0.0   1.000   NaN       0            NaN

# %%
stellar.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  990244.000000  990244.000000  990244.000000  990244.000000
# mean     5674.616938       4.200098      -0.174397       3.162848
# std       802.762263       0.682550       0.251700      10.862114
# min      2500.000000      -0.154000      -2.567000       0.104000
# 25%      5207.000000       4.218000      -0.260000       0.836000
# 50%      5776.000000       4.446000      -0.200000       1.000000
# 75%      6129.000000       4.544000      -0.034000       1.374000
# max     27730.000000       6.158000       1.000000     300.749000
#
#                 mass         nconfp  has_habitable
# count  787129.000000  990244.000000            0.0
# mean        1.102479       0.011862            NaN
# std         0.508014       0.149630            NaN
# min         0.086000       0.000000            NaN
# 25%         0.850000       0.000000            NaN
# 50%         0.988300       0.000000            NaN
# ...

# %%
#if star has an exoplanet, assign a 1 for has_exo, nan otherwise
stellar['has_exo'] = np.where(stellar['nconfp']>0, 1, np.nan)

# %%
stellar.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  990244.000000  990244.000000  990244.000000  990244.000000
# mean     5674.616938       4.200098      -0.174397       3.162848
# std       802.762263       0.682550       0.251700      10.862114
# min      2500.000000      -0.154000      -2.567000       0.104000
# 25%      5207.000000       4.218000      -0.260000       0.836000
# 50%      5776.000000       4.446000      -0.200000       1.000000
# 75%      6129.000000       4.544000      -0.034000       1.374000
# max     27730.000000       6.158000       1.000000     300.749000
#
#                 mass         nconfp  has_habitable  has_exo
# count  787129.000000  990244.000000            0.0   8274.0
# mean        1.102479       0.011862            NaN      1.0
# std         0.508014       0.149630            NaN      0.0
# min         0.086000       0.000000            NaN      1.0
# 25%         0.850000       0.000000            NaN      1.0
# ...

# %%
stellar.head()
# Out:
#    teff   logg  feh  radius  mass  nconfp  has_habitable  has_exo
# 0  6852  4.144 -0.2   1.651   NaN       0            NaN      NaN
# 1  5925  4.522 -0.2   0.913   NaN       0            NaN      NaN
# 2  6142  4.384 -0.2   1.097   NaN       0            NaN      NaN
# 3  6113  4.487 -0.2   0.979   NaN       0            NaN      NaN
# 4  5780  4.438  0.0   1.000   NaN       0            NaN      NaN

# %%
habitable['has_exo'] = 1
habitable.head()
# Out:
#    koi_steff  koi_slogg  koi_smet  koi_srad  koi_smass  nconfp  has_habitable  \
# 0     3950.0      4.754     -0.46     0.493      0.502       1              1
# 1     3593.0      4.757      0.26     0.491      0.503       1              1
# 2     2661.0      5.283      0.00     0.116      0.094       1              1
# 3     4016.0      4.658      0.02     0.599      0.595       1              1
# 4     5637.0      4.399     -0.30     0.943      0.813       1              1
#
#    has_exo
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
habitable.rename(columns={'koi_steff':'teff',
                          'koi_slogg':'logg',
                          'koi_smet': 'feh',
                          'koi_srad': 'radius',
                          'koi_smass': 'mass'}, 
                 inplace=True)

# %%
habitable.head()
# Out:
#      teff   logg   feh  radius   mass  nconfp  has_habitable  has_exo
# 0  3950.0  4.754 -0.46   0.493  0.502       1              1        1
# 1  3593.0  4.757  0.26   0.491  0.503       1              1        1
# 2  2661.0  5.283  0.00   0.116  0.094       1              1        1
# 3  4016.0  4.658  0.02   0.599  0.595       1              1        1
# 4  5637.0  4.399 -0.30   0.943  0.813       1              1        1

# %%
stellar.head()
# Out:
#    teff   logg  feh  radius  mass  nconfp  has_habitable  has_exo
# 0  6852  4.144 -0.2   1.651   NaN       0            NaN      NaN
# 1  5925  4.522 -0.2   0.913   NaN       0            NaN      NaN
# 2  6142  4.384 -0.2   1.097   NaN       0            NaN      NaN
# 3  6113  4.487 -0.2   0.979   NaN       0            NaN      NaN
# 4  5780  4.438  0.0   1.000   NaN       0            NaN      NaN

# %%
# Grab a random subset of the stellar data to limit the dataset for predictions but keep all habitables
stellar = stellar.sample(100000).reset_index(drop=True)

# %%
df = pd.concat([habitable, stellar])
df.shape
# Out:
# (100051, 8)

# %%
df.describe()
# Out:
#                 teff           logg            feh         radius  \
# count  100051.000000  100051.000000  100051.000000  100051.000000
# mean     5673.333160       4.196263      -0.173744       3.205106
# std       801.948288       0.689142       0.250547      10.897462
# min      2661.000000      -0.067000      -2.500000       0.106000
# 25%      5204.000000       4.215000      -0.260000       0.836000
# 50%      5775.000000       4.446000      -0.200000       1.000000
# 75%      6127.000000       4.544000      -0.040000       1.380000
# max     15896.000000       6.026000       0.870000     300.749000
#
#                mass         nconfp  has_habitable  has_exo
# count  79571.000000  100051.000000           51.0    877.0
# mean       1.102653       0.012044            1.0      1.0
# std        0.509219       0.147085            0.0      0.0
# min        0.093900       0.000000            1.0      1.0
# 25%        0.850050       0.000000            1.0      1.0
# ...

# %%
df.shape
# Out:
# (100051, 8)

# %%
df = df.drop_duplicates()

# %%
df[df.has_exo == 1].shape
# Out:
# (831, 8)

# %%
df.has_exo = df.has_exo.fillna(0)

# %%
df[df.has_exo == 0].shape
# Out:
# (64430, 8)

# %%
df = df.fillna(0).reset_index(drop=True)

# %%
df_X = df[[x for x in df.columns if x != 'has_habitable']]

# %%
df_y = df[[x for x in df.columns if x == 'has_habitable']]

# %%
# Only 51 habitable planets?!?!
df_y[df_y.has_habitable > 0].shape
# Out:
# (51, 1)

# %%
# Out of 320,000 ?!?! 
df_y.shape
# Out:
# (65261, 1)

# %% [markdown]
# ### Random forest

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_X.fillna(0), df_y.fillna(0), test_size=0.2, random_state=1, shuffle=True)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1, shuffle=True)

# %%
from sklearn.metrics import hamming_loss, classification_report, roc_auc_score, confusion_matrix, average_precision_score,log_loss,f1_score,accuracy_score,hamming_loss
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import cross_val_score

rfc = RandomForestClassifier(class_weight='balanced', n_estimators=300, verbose=1, oob_score=True)
rfc.fit(X_train.fillna(0), y_train)
predictions = rfc.predict(X_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.2s finished

# %%
# Function to show results
def show_results(y_true, preds, threshold=0.5):
    binary_predictions = preds > threshold
    # summarize the fit of the model
    print("Your classification report: ")
    print(classification_report(y_true, binary_predictions))
    print("-----------------------------")
    #print("Log loss:", current_log_loss)
    print("F1 macro:", f1_score(y_true, binary_predictions, average='macro'))
    print("Hamming Loss:", hamming_loss(y_true, binary_predictions))

    print(confusion_matrix(y_true, binary_predictions.astype(int)))
    print("-----------------------------")
    print("Continuous prediction metrics:")
    # Adding metrics from previous versions
    print("Log Loss:", log_loss(y_true, preds))
    print("ROC AUC:", roc_auc_score(y_true, preds))
    print("-----------------------------")
    

predictions = rfc.predict_proba(X_test)[:, 1]
show_results(y_test, predictions)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Your classification report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     13046
#          1.0       0.38      0.43      0.40         7
#
#    micro avg       1.00      1.00      1.00     13053
#    macro avg       0.69      0.71      0.70     13053
# weighted avg       1.00      1.00      1.00     13053
#
# -----------------------------
# F1 macro: 0.6998275267333562
# Hamming Loss: 0.000689496667432774
# [[13041     5]
#  [    4     3]]
# -----------------------------
# Continuous prediction metrics:
# Log Loss: 0.004706811831489953
# ROC AUC: 0.9253794266441822
# -----------------------------
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.2s finished

# %%
from matplotlib import pyplot as plt

# %%
feature_importance = rfc.feature_importances_

# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())

# A threshold below which to drop features from the final data set. Specifically, this number represents
# the percentage of the most important feature's importance value
fi_threshold = 5

# Get the indexes of all features over the importance threshold
important_idx = np.where(feature_importance > fi_threshold)[0]

# Create a list of all the feature names above the importance threshold
features_list = np.array(list(X_train))
important_features = features_list[important_idx]
print("n", important_features.shape[0], "Important features(>", fi_threshold, "% of max importance):n", important_features)

# Get the sorted indexes of important features
sorted_idx = np.argsort(feature_importance[important_idx])[::-1]
# print("nFeatures sorted by importance (DESC):n", important_features[sorted_idx])

pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[important_idx][sorted_idx[::-1]], align='center')
plt.yticks(pos, important_features[sorted_idx[::-1]])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.draw()
plt.show()
# Out:
# n 6 Important features(> 5 % of max importance):n ['teff' 'logg' 'radius' 'mass' 'nconfp' 'has_exo']
